# %%
import pandas as pd   #to create dataframe
import requests       #to send the request to the URL
from bs4 import BeautifulSoup #to get the content in the form of HTML
import numpy as np  # to count the values (in our case)

# %%
url = 'https://www.imdb.com/list/ls009997493/'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
movie_name=[]
year = []
time = []
rating = []

# %%
movie_data = soup.findAll('div', attrs= {'class': 'lister-item mode-detail'})

#calling one by one using for loop
for store in movie_data:
    name = store.h3.a.text
    movie_name.append(name)
    
    year_of_release = store.h3.find('span', class_ = 'lister-item-year text-muted unbold').text.replace('(', '').replace(')', '')
    year.append(year_of_release)
    
    runtime = store.p.find('span', class_ = 'runtime').text.replace(' min', '')
    time.append(runtime)
    
    rate = store.find('div', class_ = 'ipl-rating-widget').text.replace('\n', '')
    rating.append(rate)

# %%
movie_DF = pd.DataFrame({'Name of movie': movie_name, 'Year of relase': year, 'Watchtime': time, 'Movie Rating': rating})

# %%
movie_DF.head(100)
# Out:
#              Name of movie Year of relase Watchtime  \
# 0          Rang De Basanti           2006       167
# 1                 3 Idiots           2009       170
# 2         Taare Zameen Par           2007       165
# 3           Dil Chahta Hai           2001       183
# 4   Swades: We, the People           2004       210
# ..                     ...            ...       ...
# 95             Wake Up Sid           2009       138
# 96                Rangeela           1995       142
# 97     Shatranj Ke Khilari           1977       129
# 98      Pyaar Ka Punchnama           2011       149
# 99           Ek Hasina Thi           2004       120
#
#                                          Movie Rating
# 0   8.10Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 1   8.40Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 2   8.30Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 3   8.10Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 4   8.10Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# ..                                                ...
# 95  7.60Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 96  7.40Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 97  7.50Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 98  7.60Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
# 99  7.50Rate 1Rate2Rate3Rate4Rate5Rate6Rate7Rate8R...
#
# [100 rows x 4 columns]
